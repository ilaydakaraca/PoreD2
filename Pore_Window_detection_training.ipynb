# %% [markdown]
# <a href="https://colab.research.google.com/github/ilaydakaraca/PoreD2/blob/main/Pore_Window_detection_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-295-gac6c4383 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.9/78.2 GB disk)

# %%
# !unzip "/content/line.zip" -d "/content"
# Out:
# Archive:  /content/line.zip
#  extracting: /content/README.dataset.txt
#  extracting: /content/README.roboflow.txt
#  extracting: /content/data.yaml
#    creating: /content/train/
#    creating: /content/train/images/
#  extracting: /content/train/images/5_07_png.rf.871d69f9d693f9789616578355c29ce2.jpg
#  extracting: /content/train/images/Betul-1_01_png.rf.2f34bdad6fcb94b3c53e9563598be657.jpg
#  extracting: /content/train/images/Betul-1_02_png.rf.232b66d01aac168d3c5e572014661c56.jpg
#  extracting: /content/train/images/Betul-1_04_png.rf.7ee21eedd851ce5c355035da9faa4d4e.jpg
#  extracting: /content/train/images/Betul-1_05_png.rf.e6af17f5684a701d0c38cfe872879f31.jpg
#  extracting: /content/train/images/Betul-1_07_png.rf.5568f035c96244ca899da06089316d31.jpg
#  extracting: /content/train/images/Betul-1_09_png.rf.c23535d557549edf03b45c1002ccdbfd.jpg
#  extracting: /content/train/images/Betul-2_01_png.rf.7b31dab177e5348507fc00ba088eb6c5.jpg
# ...

# %%
dataset = "/content/deneme"

# %%
# !python train.py --img 640 --batch 16 --epochs 200 --data {dataset}/data.yaml --weights yolov5x6.pt --cache --patience 0
# Out:
# train: weights=yolov5x6.pt, cfg=, data=/content/deneme/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=0, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-224-g6262c7f Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !zip -r /content/6 ///content/yolov5/runs/train
# Out:
#   adding: content/yolov5/runs/train/ (stored 0%)
#   adding: content/yolov5/runs/train/exp/ (stored 0%)
#   adding: content/yolov5/runs/train/exp/labels_correlogram.jpg (deflated 50%)
#   adding: content/yolov5/runs/train/exp/train_batch0.jpg (deflated 1%)
#   adding: content/yolov5/runs/train/exp/R_curve.png (deflated 21%)
#   adding: content/yolov5/runs/train/exp/opt.yaml (deflated 49%)
#   adding: content/yolov5/runs/train/exp/weights/ (stored 0%)
#   adding: content/yolov5/runs/train/exp/weights/best.pt (deflated 8%)
#   adding: content/yolov5/runs/train/exp/weights/last.pt (deflated 8%)
#   adding: content/yolov5/runs/train/exp/val_batch0_pred.jpg (deflated 9%)
#   adding: content/yolov5/runs/train/exp/train_batch1.jpg (deflated 1%)
#   adding: content/yolov5/runs/train/exp/events.out.tfevents.1695975984.f63b5ea2842e.1282.0 (deflated 62%)
#   adding: content/yolov5/runs/train/exp/confusion_matrix.png (deflated 43%)
# ...

# %%
# Tensorboard  (optional)
# %load_ext tensorboard
#%reload_ext tensorboard
# %tensorboard --logdir segment/runs/train

#!kill 110511

# %%
# !python detect.py --weights /content/drive/MyDrive/SEM_DENEME/bestpore.pt --source /content/MEHMET2.png --line-thickness 2 --hide-labels --hide-conf
# Out:
# detect: weights=['/content/drive/MyDrive/SEM_DENEME/bestpore.pt'], source=/content/MEHMET2.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=2, hide_labels=True, hide_conf=True, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-203-g0897415 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 416 layers, 139970872 parameters, 0 gradients, 207.9 GFLOPs
# image 1/1 /content/MEHMET2.png: 512x640 40 poress, 69.7ms
# Speed: 0.6ms pre-process, 69.7ms inference, 72.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', '/content/drive/MyDrive/SEM_DENEME/bestpore.pt')
im = '/content/MEHMET2.png'
results = model(im)
results.print()
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 v7.0-203-g0897415 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 416 layers, 139970872 parameters, 0 gradients, 207.9 GFLOPs
# Adding AutoShape...
# image 1/1: 1103x1536 40 poress
# Speed: 82.6ms pre-process, 80.2ms inference, 1.9ms NMS per image at shape (1, 3, 512, 640)

# %%
results.pandas().xywh[0].to_excel("/content/mehmet2p.xlsx")

# %%
results.pandas().xyxy[0].to_csv("deneme.csv")

# %%
import pandas
df = pandas.read_csv('denemeee.csv')
print(df)

# %%
# !python detect.py --weights /content/best.pt --source /content/18_image --line-thickness 2 --hide-labels --hide-conf

# %%
# !python detect.py --weights /content/best.pt --source /content/2.jpg --line-thickness 2 --hide-labels --hide-conf
